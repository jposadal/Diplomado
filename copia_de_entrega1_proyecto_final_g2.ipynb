# %% [markdown]
# <a href="https://colab.research.google.com/github/jposadal/Diplomado/blob/main/copia_de_entrega1_proyecto_final_g2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git-python

# %%
from git import Repo

# %%
diplomado = Repo.clone_from("https://github.com/jposadal/Diplomado", branch="main", to_path="/content/Diplomado")
# Out:
# ---------------------------------------------------------------------------
# GitCommandError                           Traceback (most recent call last)
# <ipython-input-8-a87658ddb553> in <cell line: 1>()
# ----> 1 diplomado = Repo.clone_from("https://github.com/jposadal/Diplomado", branch="main", to_path="/content/Diplomado")
#
# /usr/local/lib/python3.10/dist-packages/git/repo/base.py in clone_from(cls, url, to_path, progress, env, multi_options, allow_unsafe_protocols, allow_unsafe_options, **kwargs)
#    1523         if env is not None:
#    1524             git.update_environment(**env)
# -> 1525         return cls._clone(
#    1526             git,
#    1527             url,
#
# /usr/local/lib/python3.10/dist-packages/git/repo/base.py in _clone(cls, git, url, path, odb_default_type, progress, multi_options, allow_unsafe_protocols, allow_unsafe_options, **kwargs)
#    1394
#    1395             _logger.debug("Cmd(%s)'s unused stdout: %s", cmdline, stdout)
# ...

# %%
diplomado.git.pull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d4aff0c26a98> in <cell line: 1>()
# ----> 1 diplomado.git.pull()
#
# NameError: name 'diplomado' is not defined

# %%
# !git lfs install
# Out:
# Updated git hooks.
# Git LFS initialized.

# %%
# !git remote add origin https://jposadal:2d3M@rz0d31972@github.com/jposadal/Diplomado.git
# Out:
# error: remote origin already exists.

# %%
# !git config --global user.name "@jposadal"
# !git config --global user.email "jposadal@gmail.com"

# %%
! git clone https://github.com/jposadal/Diplomado.git
# Out:
# fatal: destination path 'Diplomado' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/Proyecto Diplomado')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
casos = pd.read_csv('/content/Diplomado/CASOS.csv', sep=';', dtype=str)
casos.info()
casos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163253 entries, 0 to 163252
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   codigo_municipio  163253 non-null  object
#  1   anno              163253 non-null  object
#  2   cantidad          163253 non-null  object
#  3   delito            163253 non-null  object
# dtypes: object(4)
# memory usage: 5.0+ MB
#   codigo_municipio  anno cantidad delito
# 0            05001  2010      815      1
# 1            05001  2010        1      3
# 2            05001  2010        6      4
# 3            05001  2010       98      5
# 4            05001  2011     2001      1

# %%
casos['codigo_municipio'] = casos['codigo_municipio'].astype("string")
casos.info()
casos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163253 entries, 0 to 163252
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   codigo_municipio  163253 non-null  string
#  1   anno              163253 non-null  object
#  2   cantidad          163253 non-null  object
#  3   delito            163253 non-null  object
# dtypes: object(3), string(1)
# memory usage: 5.0+ MB
#   codigo_municipio  anno cantidad delito
# 0            05001  2010      815      1
# 1            05001  2010        1      3
# 2            05001  2010        6      4
# 3            05001  2010       98      5
# 4            05001  2011     2001      1

# %%
casos['cantidad'] = casos['cantidad'].astype("int64")
casos['delito'] = casos['delito'].astype("int64")
casos['anno'] = casos['anno'].astype("int64")
casos.info()
casos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163253 entries, 0 to 163252
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   codigo_municipio  163253 non-null  string
#  1   anno              163253 non-null  int64
#  2   cantidad          163253 non-null  int64
#  3   delito            163253 non-null  int64
# dtypes: int64(3), string(1)
# memory usage: 5.0 MB
#   codigo_municipio  anno  cantidad  delito
# 0            05001  2010       815       1
# 1            05001  2010         1       3
# 2            05001  2010         6       4
# 3            05001  2010        98       5
# 4            05001  2011      2001       1

# %%
delitos = pd.read_csv('/content/Diplomado/DELITOS.csv', sep=';', dtype=str)
delitos.info()
delitos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delito         15 non-null     object
#  1   Codigo Delito  15 non-null     object
# dtypes: object(2)
# memory usage: 368.0+ bytes
#                         Delito Codigo Delito
# 0            HURTO AUTOMOTORES             1
# 1           HURTO MOTOCICLETAS             2
# 2               HURTO ABIGEATO             3
# 3  HURTO ENTIDADES FINANCIERAS             4
# 4    HURTO PIRATERÍA TERRESTRE             5

# %%
delitos['Codigo Delito'] = delitos['Codigo Delito'].astype("int64")
delitos.info()
delitos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delito         15 non-null     object
#  1   Codigo Delito  15 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 368.0+ bytes
#                         Delito  Codigo Delito
# 0            HURTO AUTOMOTORES              1
# 1           HURTO MOTOCICLETAS              2
# 2               HURTO ABIGEATO              3
# 3  HURTO ENTIDADES FINANCIERAS              4
# 4    HURTO PIRATERÍA TERRESTRE              5

# %%
municipios = pd.read_csv('/content/Diplomado/Municipios.csv', sep=';', dtype=str)
municipios.info()
municipios.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6622 entries, 0 to 6621
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigo_departamento  6621 non-null   object
#  1   codigo_municipio     6621 non-null   object
#  2   municipio            6621 non-null   object
#  3   Unnamed: 3           2 non-null      object
# dtypes: object(4)
# memory usage: 207.1+ KB
#   codigo_departamento codigo_municipio   municipio Unnamed: 3
# 0                  05            05001    MEDELLÍN        NaN
# 1                  05            05002   ABEJORRAL        NaN
# 2                  05            05004    ABRIAQUÍ        NaN
# 3                  05            05021  ALEJANDRÍA        NaN
# 4                  05            05030       AMAGÁ        NaN

# %%
municipios = municipios.drop ('Unnamed: 3', axis = 1)
municipios.head ()
# Out:
#   codigo_departamento codigo_municipio   municipio
# 0                  05            05001    MEDELLÍN
# 1                  05            05002   ABEJORRAL
# 2                  05            05004    ABRIAQUÍ
# 3                  05            05021  ALEJANDRÍA
# 4                  05            05030       AMAGÁ

# %%
municipios['codigo_municipio'] = municipios['codigo_municipio'].astype("string")
municipios['codigo_departamento'] = municipios['codigo_departamento'].astype("string")
municipios.head ()
municipios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6622 entries, 0 to 6621
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigo_departamento  6621 non-null   string
#  1   codigo_municipio     6621 non-null   string
#  2   municipio            6621 non-null   object
# dtypes: object(1), string(2)
# memory usage: 155.3+ KB

# %%
municipios.head()
# Out:
#   codigo_departamento codigo_municipio   municipio
# 0                  05            05001    MEDELLÍN
# 1                  05            05002   ABEJORRAL
# 2                  05            05004    ABRIAQUÍ
# 3                  05            05021  ALEJANDRÍA
# 4                  05            05030       AMAGÁ

# %%
departamentos = pd.read_csv('/content/Diplomado/departamentos.csv', sep=',', dtype=str)
departamentos.info()
departamentos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigo_departamento  33 non-null     object
#  1   departamento         33 non-null     object
# dtypes: object(2)
# memory usage: 672.0+ bytes
#   codigo_departamento  departamento
# 0                  05     ANTIOQUIA
# 1                  08     ATLÁNTICO
# 2                  11  BOGOTÁ, D.C.
# 3                  13       BOLÍVAR
# 4                  15        BOYACÁ

# %%
departamentos['codigo_departamento'] = departamentos['codigo_departamento'].astype("string")
departamentos.info()
departamentos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigo_departamento  33 non-null     string
#  1   departamento         33 non-null     object
# dtypes: object(1), string(1)
# memory usage: 672.0+ bytes
#   codigo_departamento  departamento
# 0                  05     ANTIOQUIA
# 1                  08     ATLÁNTICO
# 2                  11  BOGOTÁ, D.C.
# 3                  13       BOLÍVAR
# 4                  15        BOYACÁ

# %%
gini = pd.read_csv('/content/Diplomado/gini.csv', sep=',', dtype=str)
gini.info()
gini.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigo_departamento  442 non-null    object
#  1   departamento         442 non-null    object
#  2   anno                 442 non-null    object
#  3   cantidad             442 non-null    object
# dtypes: object(4)
# memory usage: 13.9+ KB
#   codigo_departamento  departamento  anno cantidad
# 0                  05     ANTIOQUIA  2010    0.561
# 1                  08     ATLÁNTICO  2010    0.496
# 2                  11  BOGOTÁ, D.C.  2010    0.526
# 3                  13       BOLÍVAR  2010    0.514
# 4                  15        BOYACÁ  2010    0.538

# %%
gini['codigo_departamento'] = gini['codigo_departamento'].astype("string")
gini['anno'] = gini['anno'].astype("int64")
gini['cantidad'] = gini['cantidad'].str.replace(',', '.')
gini['cantidad'] = gini['cantidad'].astype("float64")
gini.info()
gini.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigo_departamento  442 non-null    string
#  1   departamento         442 non-null    object
#  2   anno                 442 non-null    int64
#  3   cantidad             442 non-null    float64
# dtypes: float64(1), int64(1), object(1), string(1)
# memory usage: 13.9+ KB
#   codigo_departamento  departamento  anno  cantidad
# 0                  05     ANTIOQUIA  2010     0.561
# 1                  08     ATLÁNTICO  2010     0.496
# 2                  11  BOGOTÁ, D.C.  2010     0.526
# 3                  13       BOLÍVAR  2010     0.514
# 4                  15        BOYACÁ  2010     0.538

# %%
poblacion = pd.read_csv('/content/Diplomado/poblacion.csv', sep=',', dtype=str)
poblacion.info()
poblacion.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15708 entries, 0 to 15707
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigo_departamento  15708 non-null  object
#  1   codigo_municipio     15708 non-null  object
#  2   anno                 15708 non-null  object
#  3   poblacion            15708 non-null  object
#  4   codigo               15708 non-null  object
# dtypes: object(5)
# memory usage: 613.7+ KB
#   codigo_departamento codigo_municipio  anno  poblacion   codigo
# 0                  05            05001  2010  2185539.0  2010_05
# 1                  05            05001  2011  2213549.0  2011_05
# 2                  05            05001  2012  2240690.0  2012_05
# 3                  05            05001  2013  2266969.0  2013_05
# 4                  05            05001  2014  2293601.0  2014_05

# %%
poblacion['codigo_municipio'] = poblacion['codigo_municipio'].astype("string")
poblacion['codigo_departamento'] = poblacion['codigo_departamento'].astype("string")
poblacion['anno'] = poblacion['anno'].astype("int64")
poblacion ['poblacion'] = poblacion['poblacion'].str.replace('.', '')
poblacion['poblacion'] = poblacion['poblacion'].astype("float64")
poblacion.info()
poblacion.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15708 entries, 0 to 15707
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigo_departamento  15708 non-null  string
#  1   codigo_municipio     15708 non-null  string
#  2   anno                 15708 non-null  int64
#  3   poblacion            15708 non-null  float64
#  4   codigo               15708 non-null  object
# dtypes: float64(1), int64(1), object(1), string(2)
# memory usage: 613.7+ KB
#   codigo_departamento codigo_municipio  anno   poblacion   codigo
# 0                  05            05001  2010  21855390.0  2010_05
# 1                  05            05001  2011  22135490.0  2011_05
# 2                  05            05001  2012  22406900.0  2012_05
# 3                  05            05001  2013  22669690.0  2013_05
# 4                  05            05001  2014  22936010.0  2014_05

# %%
merged_df = pd.merge(casos, poblacion, on=['codigo_municipio', 'anno'], how='inner')
merged_df.head()
# Out:
#   codigo_municipio  anno  cantidad  delito codigo_departamento   poblacion  \
# 0            05001  2010       815       1                  05  21855390.0
# 1            05001  2010         1       3                  05  21855390.0
# 2            05001  2010         6       4                  05  21855390.0
# 3            05001  2010        98       5                  05  21855390.0
# 4            05001  2010      1383       8                  05  21855390.0
#
#     codigo
# 0  2010_05
# 1  2010_05
# 2  2010_05
# 3  2010_05
# 4  2010_05

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80805 entries, 0 to 80804
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigo_municipio     80805 non-null  string
#  1   anno                 80805 non-null  int64
#  2   cantidad             80805 non-null  int64
#  3   delito               80805 non-null  int64
#  4   codigo_departamento  80805 non-null  string
#  5   poblacion            80805 non-null  float64
#  6   codigo               80805 non-null  object
# dtypes: float64(1), int64(3), object(1), string(2)
# memory usage: 4.3+ MB

# %%
merged_df["indice"] =round(((merged_df["cantidad"]/merged_df["poblacion"])*100000), 2)
print(merged_df)
# Out:
#       codigo_municipio  anno  cantidad  delito codigo_departamento  \
# 0                05001  2010       815       1                  05
# 1                05001  2010         1       3                  05
# 2                05001  2010         6       4                  05
# 3                05001  2010        98       5                  05
# 4                05001  2010      1383       8                  05
# ...                ...   ...       ...     ...                 ...
# 80800            68425  2019         1      14                  68
# 80801            68425  2019         1      15                  68
# 80802            68686  2019         1      11                  68
# 80803            85136  2019         1      11                  85
# 80804            85136  2019         1      14                  85
#
#         poblacion   codigo  indice
# 0      21855390.0  2010_05    3.73
# 1      21855390.0  2010_05    0.00
# 2      21855390.0  2010_05    0.03
# ...

# %%
merged_df_dep = pd.merge(casos, municipios, on=['codigo_municipio'], how='inner')
merged_df_dep.head()
# Out:
#   codigo_municipio  anno  cantidad  delito codigo_departamento municipio
# 0            05001  2010       815       1                  05  MEDELLÍN
# 1            05001  2010         1       3                  05  MEDELLÍN
# 2            05001  2010         6       4                  05  MEDELLÍN
# 3            05001  2010        98       5                  05  MEDELLÍN
# 4            05001  2011      2001       1                  05  MEDELLÍN

# %%
merged_df_dep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149076 entries, 0 to 1149075
# Data columns (total 6 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   codigo_municipio     1149076 non-null  string
#  1   anno                 1149076 non-null  int64
#  2   cantidad             1149076 non-null  int64
#  3   delito               1149076 non-null  int64
#  4   codigo_departamento  1149076 non-null  string
#  5   municipio            1149076 non-null  object
# dtypes: int64(3), object(1), string(2)
# memory usage: 52.6+ MB

# %%
merged_df_dep = merged_df_dep.drop ('municipio', axis = 1)
merged_df_dep = merged_df_dep.drop ('codigo_municipio', axis = 1)

# %%
merged_df_dep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149076 entries, 0 to 1149075
# Data columns (total 4 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   anno                 1149076 non-null  int64
#  1   cantidad             1149076 non-null  int64
#  2   delito               1149076 non-null  int64
#  3   codigo_departamento  1149076 non-null  string
# dtypes: int64(3), string(1)
# memory usage: 35.1 MB

# %%
merged_df_dep['delito'] = merged_df_dep['delito'].astype("str")
merged_df_dep['anno'] = merged_df_dep['anno'].astype("str")
merged_df_dep['codigo'] = merged_df_dep.anno.str.cat([merged_df_dep.codigo_departamento, merged_df_dep.delito], sep="_")

# %%
merged_df_dep.info()
merged_df_dep.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149076 entries, 0 to 1149075
# Data columns (total 5 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   anno                 1149076 non-null  object
#  1   cantidad             1149076 non-null  int64
#  2   delito               1149076 non-null  object
#  3   codigo_departamento  1149076 non-null  string
#  4   codigo               1149076 non-null  object
# dtypes: int64(1), object(3), string(1)
# memory usage: 43.8+ MB
#    anno  cantidad delito codigo_departamento     codigo
# 0  2010       815      1                  05  2010_05_1
# 1  2010         1      3                  05  2010_05_3
# 2  2010         6      4                  05  2010_05_4
# 3  2010        98      5                  05  2010_05_5
# 4  2011      2001      1                  05  2011_05_1

# %%
merged_df_dep['delito'] = merged_df_dep['delito'].astype("int64")
merged_df_dep['anno'] = merged_df_dep['anno'].astype("int64")
merged_df_dep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149076 entries, 0 to 1149075
# Data columns (total 5 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   anno                 1149076 non-null  int64
#  1   cantidad             1149076 non-null  int64
#  2   delito               1149076 non-null  int64
#  3   codigo_departamento  1149076 non-null  string
#  4   codigo               1149076 non-null  object
# dtypes: int64(3), object(1), string(1)
# memory usage: 43.8+ MB

# %%
merged_df_dep_group = merged_df_dep.groupby('codigo').sum('cantidad')

# %%
merged_df_dep_group = merged_df_dep.groupby('codigo')['cantidad'].sum().reset_index()

# %%
resultado = pd.DataFrame(merged_df_dep_group)

# %%
resultado
# Out:
#           codigo  cantidad
# 0     1996_05_12        40
# 1     1996_05_13       247
# 2     1996_08_13        26
# 3     1996_11_10       248
# 4     1996_11_12         4
# ...          ...       ...
# 8547   2024_99_2        16
# 8548   2024_99_6         8
# 8549   2024_99_7        16
# 8550   2024_99_8       181
# 8551   2024_99_9        63
#
# [8552 rows x 2 columns]

# %%
depagrupado = pd.merge(resultado, merged_df_dep, on=['codigo'], how='left')

# %%
depagrupado
# Out:
#              codigo  cantidad_x  anno  cantidad_y  delito codigo_departamento
# 0        1996_05_12          40  1996           8      12                  05
# 1        1996_05_12          40  1996           1      12                  05
# 2        1996_05_12          40  1996           1      12                  05
# 3        1996_05_12          40  1996           2      12                  05
# 4        1996_05_12          40  1996           1      12                  05
# ...             ...         ...   ...         ...     ...                 ...
# 1149071   2024_99_9          63  2024           3       9                  99
# 1149072   2024_99_9          63  2024           3       9                  99
# 1149073   2024_99_9          63  2024           3       9                  99
# 1149074   2024_99_9          63  2024           3       9                  99
# 1149075   2024_99_9          63  2024           3       9                  99
#
# [1149076 rows x 6 columns]

# %%
depagrupado = depagrupado .drop(columns=['cantidad_y'])

# %%
depagrupado.info()
depagrupado.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149076 entries, 0 to 1149075
# Data columns (total 5 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   codigo               1149076 non-null  object
#  1   cantidad_x           1149076 non-null  int64
#  2   anno                 1149076 non-null  int64
#  3   delito               1149076 non-null  int64
#  4   codigo_departamento  1149076 non-null  string
# dtypes: int64(3), object(1), string(1)
# memory usage: 43.8+ MB
#        codigo  cantidad_x  anno  delito codigo_departamento
# 0  1996_05_12          40  1996      12                  05
# 1  1996_05_12          40  1996      12                  05
# 2  1996_05_12          40  1996      12                  05
# 3  1996_05_12          40  1996      12                  05
# 4  1996_05_12          40  1996      12                  05

# %%
depagrupado.columns = ['codigo', 'cantidad', 'anno', 'delito', 'codigo_departamento']
depagrupado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149076 entries, 0 to 1149075
# Data columns (total 5 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   codigo               1149076 non-null  object
#  1   cantidad             1149076 non-null  int64
#  2   anno                 1149076 non-null  int64
#  3   delito               1149076 non-null  int64
#  4   codigo_departamento  1149076 non-null  string
# dtypes: int64(3), object(1), string(1)
# memory usage: 43.8+ MB

# %%
poblacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15708 entries, 0 to 15707
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigo_departamento  15708 non-null  string
#  1   codigo_municipio     15708 non-null  string
#  2   anno                 15708 non-null  int64
#  3   poblacion            15708 non-null  float64
#  4   codigo               15708 non-null  object
# dtypes: float64(1), int64(1), object(1), string(2)
# memory usage: 613.7+ KB

# %%
poblacion['anno'] = poblacion['anno'].astype("str")
poblacion['codigo'] = poblacion.anno.str.cat([poblacion.codigo_departamento], sep="_")
poblacion['anno'] = poblacion['anno'].astype("int64")

# %%
poblacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15708 entries, 0 to 15707
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigo_departamento  15708 non-null  string
#  1   codigo_municipio     15708 non-null  string
#  2   anno                 15708 non-null  int64
#  3   poblacion            15708 non-null  float64
#  4   codigo               15708 non-null  object
# dtypes: float64(1), int64(1), object(1), string(2)
# memory usage: 613.7+ KB

# %%
grouppob = poblacion.groupby('codigo')['poblacion'].sum().reset_index()
pobgroupcod = pd.DataFrame(grouppob)

# %%
pobgroupcod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   codigo     462 non-null    object
#  1   poblacion  462 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 7.3+ KB

# %%
poblaciondep = pd.merge(pobgroupcod, poblacion, on=['codigo'], how='left')

# %%
poblaciondep.head()
# Out:
#     codigo  poblacion_x codigo_departamento codigo_municipio  anno  \
# 0  2010_05   58001600.0                  05            05001  2010
# 1  2010_05   58001600.0                  05            05002  2010
# 2  2010_05   58001600.0                  05            05004  2010
# 3  2010_05   58001600.0                  05            05021  2010
# 4  2010_05   58001600.0                  05            05030  2010
#
#    poblacion_y
# 0   21855390.0
# 1     218220.0
# 2      26550.0
# 3      46790.0
# 4     281320.0

# %%
poblaciondep = poblaciondep.drop(columns=['poblacion_y', 'codigo_municipio'])

# %%
poblaciondep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15708 entries, 0 to 15707
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigo               15708 non-null  object
#  1   poblacion_x          15708 non-null  float64
#  2   codigo_departamento  15708 non-null  string
#  3   anno                 15708 non-null  int64
# dtypes: float64(1), int64(1), object(1), string(1)
# memory usage: 491.0+ KB

# %%
poblaciondep.columns = ['codigo', 'poblacion', 'codigo_departamento', 'anno']
poblaciondep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15708 entries, 0 to 15707
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   codigo               15708 non-null  object
#  1   poblacion            15708 non-null  float64
#  2   codigo_departamento  15708 non-null  string
#  3   anno                 15708 non-null  int64
# dtypes: float64(1), int64(1), object(1), string(1)
# memory usage: 491.0+ KB

# %%
poblaciondep = poblaciondep.drop(columns=['codigo'])
depagrupado = depagrupado.drop(columns=['codigo'])

# %%
depindices2 = pd.merge(poblaciondep, depagrupado, on=['codigo_departamento', 'anno'], how='inner')
depindices2.head()
# Out:
#     poblacion codigo_departamento  anno  cantidad  delito
# 0  58001600.0                  05  2010      1125       1
# 1  58001600.0                  05  2010      1125       1
# 2  58001600.0                  05  2010      1125       1
# 3  58001600.0                  05  2010      1125       1
# 4  58001600.0                  05  2010      1125       1

# %%
gini.head()
# Out:
#   codigo_departamento  departamento  anno  cantidad
# 0                  05     ANTIOQUIA  2010     0.561
# 1                  08     ATLÁNTICO  2010     0.496
# 2                  11  BOGOTÁ, D.C.  2010     0.526
# 3                  13       BOLÍVAR  2010     0.514
# 4                  15        BOYACÁ  2010     0.538

# %%
depindices = pd.merge(depindices2, gini, on=['codigo_departamento', 'anno'], how='inner')
depindices.head()
# Out:
#     poblacion codigo_departamento  anno  cantidad_x  delito departamento  \
# 0  58001600.0                  05  2010        1125       1    ANTIOQUIA
# 1  58001600.0                  05  2010        1125       1    ANTIOQUIA
# 2  58001600.0                  05  2010        1125       1    ANTIOQUIA
# 3  58001600.0                  05  2010        1125       1    ANTIOQUIA
# 4  58001600.0                  05  2010        1125       1    ANTIOQUIA
#
#    cantidad_y
# 0       0.561
# 1       0.561
# 2       0.561
# 3       0.561
# 4       0.561

# %%
depindices.columns = ['poblacion', 'codigo_departamento', 'anno', 'cantidad', 'delito', 'departamento', 'gini']

# %%
depindices["indice"] =round(((depindices["cantidad"]/depindices["poblacion"])*100000), 2)
print(depindices)
# Out:
#            poblacion codigo_departamento  anno  cantidad  delito departamento  \
# 0         58001600.0                  05  2010      1125       1    ANTIOQUIA
# 1         58001600.0                  05  2010      1125       1    ANTIOQUIA
# 2         58001600.0                  05  2010      1125       1    ANTIOQUIA
# 3         58001600.0                  05  2010      1125       1    ANTIOQUIA
# 4         58001600.0                  05  2010      1125       1    ANTIOQUIA
# ...              ...                 ...   ...       ...     ...          ...
# 34897745   1209420.0                  99  2022       168       9      VICHADA
# 34897746   1209420.0                  99  2022       168       9      VICHADA
# 34897747   1209420.0                  99  2022       168       9      VICHADA
# 34897748   1209420.0                  99  2022       168       9      VICHADA
# 34897749   1209420.0                  99  2022       168       9      VICHADA
#
#            gini  indice
# ...

# %%
depindices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34897750 entries, 0 to 34897749
# Data columns (total 8 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   poblacion            float64
#  1   codigo_departamento  string
#  2   anno                 int64
#  3   cantidad             int64
#  4   delito               int64
#  5   departamento         object
#  6   gini                 float64
#  7   indice               float64
# dtypes: float64(3), int64(3), object(1), string(1)
# memory usage: 2.1+ GB

# %%
depindices
# Out:
#            poblacion codigo_departamento  anno  cantidad  delito departamento  \
# 0         58001600.0                  05  2010      1125       1    ANTIOQUIA
# 1         58001600.0                  05  2010      1125       1    ANTIOQUIA
# 2         58001600.0                  05  2010      1125       1    ANTIOQUIA
# 3         58001600.0                  05  2010      1125       1    ANTIOQUIA
# 4         58001600.0                  05  2010      1125       1    ANTIOQUIA
# ...              ...                 ...   ...       ...     ...          ...
# 34897745   1209420.0                  99  2022       168       9      VICHADA
# 34897746   1209420.0                  99  2022       168       9      VICHADA
# 34897747   1209420.0                  99  2022       168       9      VICHADA
# 34897748   1209420.0                  99  2022       168       9      VICHADA
# 34897749   1209420.0                  99  2022       168       9      VICHADA
#
#            gini  indice
# ...

# %%
depindices.drop_duplicates(inplace=True)

# %%
print(depindices)
depindices.info()
depindices.head()
# Out:
#            poblacion codigo_departamento  anno  cantidad  delito departamento  \
# 0         58001600.0                  05  2010      1125       1    ANTIOQUIA
# 22        58001600.0                  05  2010       738      11    ANTIOQUIA
# 83        58001600.0                  05  2010         7      12    ANTIOQUIA
# 89        58001600.0                  05  2010        20      13    ANTIOQUIA
# 101       58001600.0                  05  2010      1958      14    ANTIOQUIA
# ...              ...                 ...   ...       ...     ...          ...
# 34896836   1209420.0                  99  2022        20       3      VICHADA
# 34896848   1209420.0                  99  2022        58       6      VICHADA
# 34896873   1209420.0                  99  2022       619       7      VICHADA
# 34896904   1209420.0                  99  2022       489       8      VICHADA
# 34896935   1209420.0                  99  2022       168       9      VICHADA
#
#            gini  indice
# ...

# %%
### !git config --global init.defaultBranch main
# Out:
# Reinitialized existing Git repository in /content/.git/
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> Diplomado
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached Diplomado
# hint:
# hint: See "git help submodule" for more information.
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@bff196fd69da.(none)')
# error: src refspec master does not match any
# ...

# %%
depindices.to_csv('/content/Diplomado/depindices.csv', index=False)

# %%
merged_df.to_csv('/content/Diplomado/munindices.csv', index=False)

# %%
merged_df.to_csv('/content/Diplomado/munindices.csv', index=False)
casos.to_csv('/content/Diplomado/casos.csv', index=False)
delitos.to_csv('/content/Diplomado/delitos.csv', index=False)
municipios.to_csv('/content/Diplomado/municipios.csv', index=False)
departamentos.to_csv('/content/Diplomado/departamentos.csv', index=False)
gini.to_csv('/content/Diplomado/gini.csv', index=False)
poblacion.to_csv('/content/Diplomado/poblacion.csv', index=False)

# %%
# !cp /content/Diplomado/depindices.csv /content/drive/MyDrive/Proyecto Diplomado
# Out:
# cp: cannot stat '/content/drive/MyDrive/Proyecto': No such file or directory

# %%
from google.colab import files
files.download('/content/drive/MyDrive/Proyecto Diplomado/depindices.csv')

# %%
# !git add /content/Diplomado/munindices.csv

# %%
# !git checkout -b '<archivos>'
# Out:
# Switched to a new branch '<archivos>'

# %%
# !git push origin <'main'>
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `git push origin <'main'>'

# %%
# !git push origin https://github.com/jposadal/Diplomado.git\<main\>
# Out:
# fatal: invalid refspec 'https://github.com/jposadal/Diplomado.git<main>'

# %%
# !git push origin <main>
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `newline'
# /bin/bash: -c: line 1: `git push origin <main>'
